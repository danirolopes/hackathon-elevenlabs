# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.10.0-cp310-cp310-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 48.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
import time

# %%
df = pd.read_csv('/kaggle/input/recipes/enriched_cleaned_recipes.csv')
df
# Out:
#         Unnamed: 0                                               name  \
# 0                0         arriba   baked winter squash mexican style
# 1           130923                               marinated greek feta
# 2           130921           marinated goat cheese with fresh oregano
# 3           130920                 marinated goat cheese spread   dip
# 4           130917                              marinated goat cheese
# ...            ...                                                ...
# 160867        2673  affordable basic restaurant style tomato and m...
# 160868      174846             roast pork  pernil  puerto rican style
# 160869      132386                       mean green juice  for juicer
# 160870       62781                creamy cocoa mix  extra large batch
# 160871       45886           chicken strips with sweet and sour sauce
#
#               id  minutes  contributor_id   submitted  \
# 0       137739.0     55.0         47892.0  2005-09-16
# 1       141627.0      5.0        197023.0  2005-10-17
# 2        63342.0     65.0         56081.0  2003-05-28
# 3       258115.0    195.0        444132.0  2007-10-10
# 4        56514.0   2885.0         62043.0  2003-03-18
# ...          ...      ...             ...         ...
# 160867  115199.0     15.0        118159.0  2005-04-04
# 160868  316839.0    255.0        812387.0  2008-07-31
# 160869  492690.0     17.0        442988.0  2012-12-31
# 160870  107668.0     15.0        154044.0  2005-01-05
# 160871   19266.0     30.0         27416.0  2002-02-09
#
#                                                      tags  n_steps  \
# 0       ['60-minutes-or-less', 'time-to-make', 'course...     11.0
# 1       ['15-minutes-or-less', 'time-to-make', 'course...      4.0
# 2       ['weeknight', 'time-to-make', 'course', 'main-...      2.0
# 3       ['time-to-make', 'course', 'main-ingredient', ...      6.0
# 4       ['weeknight', 'time-to-make', 'course', 'main-...      4.0
# ...                                                   ...      ...
# 160867  ['15-minutes-or-less', 'time-to-make', 'course...      6.0
# 160868  ['main-ingredient', 'cuisine', 'preparation', ...     10.0
# 160869  ['30-minutes-or-less', 'time-to-make', 'course...      2.0
# 160870  ['15-minutes-or-less', 'time-to-make', 'course...      3.0
# 160871  ['30-minutes-or-less', 'time-to-make', 'course...     20.0
#
#                                                     steps  \
# 0       ['make a choice and proceed with recipe', 'dep...
# 1       ['cut the feta cheese into 2cm cubes and place...
# 2       ['place oil , oregano and pepper in a narrow s...
# 3       ['arrange cheese in a shallow dish in a single...
# 4       ['cut goat cheese into 1 cm rounds and place i...
# ...                                                   ...
# 160867  ['in a medium saucepan', 'bring salted water ,...
# 160868  ['the night before peel garlic and with a piln...
# 160869  ['wash all ingredients thoroughly', 'run throu...
# 160870  ['mix all ingredients in a large bowl and blen...
# 160871  ['remove all fat from chicken breasts and disc...
#
#                                               description  ... rating_mean  \
# 0       autumn is my favorite time of year to cook! th...  ...         5.0
# 1       i found this simple, super-quick-to-make recip...  ...         5.0
# 2       another one from the atkins low carb cook book...  ...         5.0
# 3       a decedent spread that wins raves at potlucks ...  ...         5.0
# 4       this recipe is from the ottawa citizen. this i...  ...         5.0
# ...                                                   ...  ...         ...
# 160867  ever had this comfort soup in a restaurant?  t...  ...         3.9
# 160868  tasty roast pork, puerto rican style, marine o...  ...         3.9
# 160869  this is the recipe for "mean green" juice used...  ...         3.9
# 160870  i like this cocoa for many reasons, only one o...  ...         3.9
# 160871  a fantastic chicken recipe with a delightful s...  ...         3.9
#
#         rating_count                                        all_reviews  \
# 0                3.0  [' I used an acorn squash and recipe#137681 Sw...
# 1                8.0  ['Just delicious and a wonderful way to keep m...
# 2                1.0  ["This was really good!  I wasn't sure if I li...
# 3                3.0  ["I'm not a big fan of goat cheese, but made t...
# 4                2.0  ['This is a delicious appetizer to have on han...
# ...              ...                                                ...
# 160867          10.0  ['hello Andre,  I have finally come on to rate...
# 160868          10.0  ["Foolproof recipe for making a flavorful and ...
# 160869          10.0  ['DH and I are juicing and this is a great go ...
# 160870          10.0  ['I am feeling under-the-weather today, and ne...
# 160871          10.0  ['My  family really enjoyed these chicken stri...
#
#         calories total_fat_pdv  sugar_pdv  sodium_pdv  protein_pdv  \
# 0           51.5           0.0       13.0         0.0          2.0
# 1          280.9          18.0       39.0        23.0         36.0
# 2          284.7          16.0       10.0        24.0         46.0
# 3          555.9          58.0       13.0        56.0         83.0
# 4          325.6          13.0       10.0        27.0         13.0
# ...          ...           ...        ...         ...          ...
# 160867     291.2          26.0       73.0         7.0         13.0
# 160868    1980.0         301.0        8.0       172.0         70.0
# 160869     499.2          32.0       17.0        28.0         37.0
# 160870    1511.8         140.0      210.0       232.0        177.0
# 160871     255.8          17.0       54.0        13.0         18.0
#
#         saturated_fat_pdv  carbohydrates_pdv
# 0                     0.0                4.0
# 1                    22.0                9.0
# 2                     9.0                7.0
# 3                    73.0                4.0
# 4                    27.0               18.0
# ...                   ...                ...
# 160867               59.0                9.0
# 160868              591.0                5.0
# 160869               61.0               20.0
# 160870              151.0               26.0
# 160871               49.0                9.0
#
# [160872 rows x 22 columns]

# %%
def combine_fields(row):
    try:
        tags = row['tags'] if isinstance(row['tags'], str) else ', '.join(eval(row['tags']))
    except Exception:
        tags = ''
    try:
        ingredients = row['ingredients'] if isinstance(row['ingredients'], str) else ', '.join(eval(row['ingredients']))
    except Exception:
        ingredients = ''
    description = row['description'] if pd.notnull(row['description']) else ""
    return f"{row['name']}. Tags: {tags}. Ingredientes: {ingredients}. Descrição: {description}"

df['combined_text'] = df.apply(combine_fields, axis=1)

model = SentenceTransformer('all-MiniLM-L6-v2', device='cuda')

start_time = time.time()
batch_size = 256
texts = df['combined_text'].tolist()

embeddings = model.encode(texts, batch_size=batch_size, show_progress_bar=True)
end_time = time.time()
print(f"Time for compute embeddings: {end_time - start_time:.2f} seconds")

embeddings = np.array(embeddings).astype('float32')
embedding_dim = embeddings.shape[1]

index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings)
print(f"Total recipes indexed: {index.ntotal}")

np.save('embeddings.npy', embeddings)
faiss.write_index(index, 'faiss_index.index')

print("Embeddings and FAISS index exported!")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/629 [00:00<?, ?it/s]
# Time for compute embeddings: 395.96 seconds
# Total recipes indexed: 160872
# Embeddings and FAISS index exported!
